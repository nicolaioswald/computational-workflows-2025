# %% [markdown]
# # Computational Workflows for biomedical data

# %% [markdown]
# Welcome to the course Computational Workflows for Biomedical Data. Over the next two weeks, you will learn how to leverage nf-core pipelines to analyze biomedical data and gain hands-on experience in creating your own pipelines, with a strong emphasis on Nextflow and nf-core.
#
# Course Structure:
#
# - Week 1: You will use a variety of nf-core pipelines to analyze a publicly available biomedical study.
# - Week 2: We will shift focus to learning the basics of Nextflow, enabling you to design and implement your own computational workflows.<br>
# - Final Project: The last couple of days, you will apply your knowledge to create a custom pipeline for analyzing biomedical data using Nextflow and the nf-core template.

# %% [markdown]
# ## Basics
#
# If you have not installed all required software, please do so now asap!
#
#
# If you already installed all software, please go on and start answering the questions in this notebook. If you have any questions, don't hesitate to approach us.

# %% [markdown]
# 1. What is nf-core?

# %% [markdown]
# nf-core is a global community effort collaborating to build open-source Nextflow components and pipelines. [1]
#
# [1]: The nf-core framework for community-curated bioinformatics pipelines. Philip Ewels, Alexander Peltzer, Sven Fillinger, Harshil Patel, Johannes Alneberg, Andreas Wilm, Maxime Ulysse Garcia, Paolo Di Tommaso & Sven Nahnsen. Nat Biotechnol. 2020 Feb 13. doi: 10.1038/s41587-020-0439-x

# %% [markdown]
# 2. How many pipelines are there currently in nf-core?

# %% [markdown]
# 139

# %% [markdown]
# 3. Are there any non-bioinformatic pipelines in nf-core?

# %% [markdown]
# There are also non-bioinformatic pipelines in nf-core. rangeland [2] is a pipeline for processing satelite imaging data to estimate a trend in land-cover changes.
#
# [2]: FORCE on Nextflow: Scalable Analysis of Earth Observation Data on Commodity Clusters. Lehmann, F., Frantz, D., Becker, S., Leser, U., Hostert, P. (2021). FORCE on Nextflow: Scalable Analysis of Earth Observation Data on Commodity Clusters. In CIKM Workshops.

# %% [markdown]
# 4. Let's go back a couple of steps. What is a pipeline and what do we use it for?

# %% [markdown]
# A pipeline is a series of computational steps or execution of programs which is executed in a defined ordering. They are used to facilliate automated data analysis, enable reproducibility of research and a effiient handling of large data.

# %% [markdown]
# 5. Why do you think nf-core adheres to strict guidelines?

# %% [markdown]
# The FAIR principles as guidelines for all nf-core pipelines ensure that these are free, all components are accessible, interoperable on different systems, and results are reproducible.

# %% [markdown]
# 6. What are the main features of nf-core pipelines?

# %% [markdown]
# All nf-core pipelines:
# - have a extensive documentation
# - provide stable releases
# - use only open source tools
# - provide a continuous-integration testing for changes made in the pipeline code
# - can be ran everywhere
# - are packaged using Docker or others
#
# To summarize, nf-core implements the FAIR principles.

# %% [markdown]
# ## Let's start using the pipelines

# %% [markdown]
# 1. Find the nf-core pipeline used to measure differential abundance of genes

# %% [markdown]
# differentialabundance [3]
#
# [3]: WackerO, Jonathan Manning, Azedine Zoufir, nf-core bot, Alexander Peltzer, Cristina Tuñí i Domínguez, Dave Carlson, Steffen Möller, Marcel Ribeiro-Dantas, Harshil Patel, & James A. Fellows Yates. (2023). nf-core/differentialabundance: v1.4.0 - 2023-11-27 (1.4.0). Zenodo. https://doi.org/10.5281/zenodo.10209675

# %%
# run the pipeline in a cell 
# to run bash in jupyter notebooks, simply use ! before the command
# e.g.

# !pwd


# For the tasks in the first week, please use the command line to run your commands and simply paste the commands you used in the respective cells!
# Out:
# /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_01

# %%
# run the pipeline in the test profile using docker containers
# make sure to specify the version you want to use (use the latest one)


# !nextflow run nf-core/differentialabundance \
    --outdir differentialabundance_test  \
    -profile test,docker
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Pulling nf-core/differentialabundance ...
#  downloaded from https://github.com/nf-core/differentialabundance.git
# Launching `https://github.com/nf-core/differentialabundance` [zen_lorenz] DSL2 - revision: 3dd360fed0 [master]
#
# Downloading plugin nf-validation@1.1.3
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : zen_lorenz
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01
#   workDir                     : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /home/n_oswald/.nextflow/assets/nf-core/differentialabundance
#   userName                    : n_oswald
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : differentialabundance_test
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [44/3c58fc] NFC…Cherry_hND6_sample_number) | 0 of 2
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [44/3c58fc] NFC…Cherry_hND6_sample_number) | 0 of 2
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [44/3c58fc] NFC…Cherry_hND6_sample_number) | 1 of 2
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 0 of 1
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 0 of 1
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 0 of 1
# [ce/56768a] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 0 of 1
# [ce/56768a] NFC…, blocking:sample_number]) | 1 of 2
# [4f/c87a1f] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 0 of 1
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [4f/c87a1f] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 0 of 1
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [4f/c87a1f] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [4f/c87a1f] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [e7/6cb043] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [e7/6cb043] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [e7/6cb043] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [e7/6cb043] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [e7/6cb043] NFC…Cherry_hND6_sample_number) | 1 of 2
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [e7/6cb043] NFC…Cherry_hND6_sample_number) | 1 of 2
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [b3/78e4b3] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [e7/6cb043] NFC…Cherry_hND6_sample_number) | 1 of 2
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [b3/78e4b3] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d7/23ed5e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d7/23ed5e] NFC…Cherry_hND6_sample_number) | 0 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d7/23ed5e] NFC…Cherry_hND6_sample_number) | 1 of 2
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [b3/78e4b3] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [b3/78e4b3] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [8a/26fcdd] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [b3/78e4b3] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [8a/26fcdd] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [b3/78e4b3] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [8a/26fcdd] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [33/bc9473] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [b3/78e4b3] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [8a/26fcdd] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [33/bc9473] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [29/7bd6d1] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [31/70bde3] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [b1/0e18ef] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [e1/e3f183] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [47/fbcb4c] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [ba/67b56e] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [23/66b99f] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [5a/3a9fcb] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [a2/4d64c1] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [fa/1015f9] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [b3/78e4b3] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/2e4019] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [4d/71a4c6] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [53/90b18a] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [8a/26fcdd] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [33/bc9473] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 11:34:24
# Duration    : 11m 4s
# CPU hours   : 0.1
# Succeeded   : 21

# %%
# repeat the run. What did change?

# !nextflow run nf-core/differentialabundance \
    --outdir differentialabundance_test  \
    -profile test,docker
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [admiring_noether] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : admiring_noether
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01
#   workDir                     : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /home/n_oswald/.nextflow/assets/nf-core/differentialabundance
#   userName                    : n_oswald
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : differentialabundance_test
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (2)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (3)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (3)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (5)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (6)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 0 of 2
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (6)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (7)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (7)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (7)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM | 0 of 1
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (9)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 0 of 1
# [29/75be9d] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#
# executor >  local (10)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 0 of 1
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (10)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 0 of 1
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (11)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 0 of 1
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [29/75be9d] NFC…, blocking:sample_number]) | 1 of 2
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 0 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 0 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 0 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [bd/e3fed2] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [bd/e3fed2] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [bd/e3fed2] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [ee/80e96d] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [94/83a140] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [d2/edc06c] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [5e/902df4] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [bd/e3fed2] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 11:42:00
# Duration    : 2m 48s
# CPU hours   : 0.1
# Succeeded   : 21

# %% [markdown]
# The pipeline ran much faster than in the first run (2m 48s vs. 11m 4s)

# %%
# now set -resume to the command. What did change?

# !nextflow run nf-core/differentialabundance \
    --outdir differentialabundance_test  \
    -profile test,docker \
    -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [spontaneous_shannon] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : spontaneous_shannon
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01
#   workDir                     : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /home/n_oswald/.nextflow/assets/nf-core/differentialabundance
#   userName                    : n_oswald
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : differentialabundance_test
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [86/6d074c] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1, cached: 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [5a/6dfbf3] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [5a/6dfbf3] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [5a/6dfbf3] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [5a/6dfbf3] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [5a/6dfbf3] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [bd/e3fed2] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [5a/6dfbf3] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [bd/e3fed2] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [8f/72a41f] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [66/f97b7a] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [f2/ce1226] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [d7/fec9b4] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [e9/8e18a5] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [7d/b613e8] NFC…, target:hND6, blocking:]) | 2 of 2, cached: 2 ✔
# [56/cfaa56] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [b8/e7070b] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [86/5be2f7] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [38/35c8dc] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [8c/c498da] NFC… (treatment_mCherry_hND6_) | 2 of 2, cached: 2 ✔
# [71/603b3c] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [f3/900a7f] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [5a/6dfbf3] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [6d/8ece37] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [bd/e3fed2] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔

# %% [markdown]
# The runtime was even faster (46.5s). Usage of cached files is indicated in the output of the workflow.

# %% [markdown]
# Check out the current directory. Next to the outdir you specified, what else has changed?

# %% [markdown]
# - a `.log` file has been created for each run of the pipeline
# - `work` directory with temporary files documenting all intermediate steps and progress of the pipeline
# - `.nextflow` directory for internal Nextflow files and a history of the pipeline runs

# %% [markdown]
# The `-resume` flag tells nextflow to restart a pipeline that has not been executed properly. Cached results from the previous run are used instead of running all steps from the beginning.

# %%
# delete the work directory and run the pipeline again using -resume. What did change?

# !rm -r work

# !nextflow run nf-core/differentialabundance \
    --outdir differentialabundance_test  \
    -profile test,docker \
    -resume
# Out:
# rm: cannot remove 'work': No such file or directory
#
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [condescending_saha] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : condescending_saha
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01
#   workDir                     : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/ComputationalWorkflows/computational-workflows-2025/notebooks/day_01/work
#   projectDir                  : /home/n_oswald/.nextflow/assets/nf-core/differentialabundance
#   userName                    : n_oswald
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : differentialabundance_test
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (4)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [b5/cab0cb] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [b5/cab0cb] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 0 of 1
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 0 of 1
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 0 of 1
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 0 of 1
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 0 of 1
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 1
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [a6/eed69c] NFC…, target:hND6, blocking:]) | 1 of 2
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c9/166833] NFC…Cherry_hND6_sample_number) | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c9/166833] NFC…Cherry_hND6_sample_number) | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c9/166833] NFC…Cherry_hND6_sample_number) | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [96/346888] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 0 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c9/166833] NFC…Cherry_hND6_sample_number) | 1 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [55/4abe7c] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c9/166833] NFC…Cherry_hND6_sample_number) | 1 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c9/166833] NFC…Cherry_hND6_sample_number) | 1 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 1 of 2
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [c9/166833] NFC…Cherry_hND6_sample_number) | 1 of 2
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 1 of 2
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 1 of 2
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [35/41bff4] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [35/41bff4] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [35/41bff4] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (20)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [35/41bff4] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE | 0 of 1
#
# executor >  local (21)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [35/41bff4] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [28/8bfdd4] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (21)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [35/41bff4] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [28/8bfdd4] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (21)
# [24/e97167] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [3f/e50a1b] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [17/332d34] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [42/90ce97] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [41/a9fb11] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [8d/c4c1c6] NFC…, blocking:sample_number]) | 2 of 2 ✔
# [65/f297bb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [ca/f229bd] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [db/048636] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [20/5067e1] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [d0/ad1526] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [72/e84231] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [2f/e28ce8] NFC…Cherry_hND6_sample_number) | 2 of 2 ✔
# [33/018573] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [35/41bff4] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [28/8bfdd4] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 29-Sep-2025 11:57:24
# Duration    : 2m 59s
# CPU hours   : 0.1
# Succeeded   : 21

# %% [markdown]
# What changed?

# %% [markdown]
# The runtime was 2m 59s. That's approximately the runtime of the rerun of the pipeline without the -resume flag.

# %% [markdown]
# ## Lets look at the results

# %% [markdown]
# ### What is differential abundance analysis?

# %% [markdown]
# Give the most important plots from the report:

# %% [markdown]
# ![Volcano_plot](./figures/volcano.png)
#
# Volcano plot visualizing the differentially expressed genes between the conditions.
#
# ![PCA_plot](./figures/pca2d.png)
#
# Principal Component Analysis plot visualizing the PCA result. A clustering of the samples based on their profiles can be recognized.
