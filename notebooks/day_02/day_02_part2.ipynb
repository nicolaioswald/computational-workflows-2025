# %% [markdown]
# ## Great, now that we discussed a little let's continue

# %% [markdown]
# Given that the current approach utilized by the authors lacks reproducibility, we will explore an alternative method by leveraging nf-core pipelines for data analysis.
#
# Please explain, how we will achieve reproducibility for the course  with this approach.

# %% [markdown]
# nf-core pipelines provide standardized, versioned pipelines that ensure reproducible results. All input (samplesheets, profiles, additional parameters) can be specified and is reported in logfiles. Therefore a rerun with the same command will result in identical results.

# %% [markdown]
# You have successfully downloaded 2 of the fastq files we will use in our study.
#
# What is the next step if we want to first have a count table and check the quality of our fastq files? What is the pipeline called to do so?

# %% [markdown]
# `nf-core/rnaseq`

# %% [markdown]
# Analyze the 2 files using an nf-core pipeline.
#
# What does this pipeline do?
#
# Which are the main tools that will be used in the pipeline?

# %% [markdown]
# rnaseq takes a samplesheet with fastq files, performs QC, trimming, alignment to a reference, and produces a gene expression matrix together with QC reports.
#
# The main tools are:
# - FastQC for quality control
# - TrimGalore! for adapter trimming
# - STAR or HiSAT2 for genome alignment and quantification
# - SAMtools, picard, BEDtools for post-processing
# - StringTie to assemble RNA-seq alignments into potential transcripts
# - RSeQC, DESeq2, MultiQC for final QC

# %% [markdown]
# As all other nf-core pipelines, the chosen pipeline takes in a samplesheet as input.
#
# Use Python and pandas to create the samplesheet for your 2 samples. Feel free to make use of the table you created earlier today.
#
# Choose your sample names wisely, they must be the connection of the results to the metadata. If you can't find the sample in the metadata later, the analysis was useless.

# %%
import pandas as pd
# create samplesheet
df = pd.read_csv("./fetchngs/samplesheet/samplesheet.csv")
df = df[["run_accession", "fastq_1", "fastq_2"]]

df['strandedness'] = 'auto'

# replace run_accession by column names in conditions_filtered.csv where there is True
conditions = pd.read_csv('conditions_filtered.csv')

combis = conditions[conditions['Run'].isin(df['run_accession'])]
combis = combis.set_index('Run').apply(lambda x: '-'.join(x.index[x].tolist()), axis=1).reset_index()[0]

# add sample column
df.insert(loc = 0, column = 'sample', value = combis)
df.drop(columns=['run_accession'], inplace=True)
# Write samplesheet.csv
df.to_csv("samplesheet.csv", index=False)

# %%
# Download GRCm39 reference genome and GTF file
# !wget https://ftp.ensembl.org/pub/release-115/fasta/mus_musculus/dna/Mus_musculus.GRCm39.dna.toplevel.fa.gz
# !wget https://ftp.ensembl.org/pub/release-115/gtf/mus_musculus/Mus_musculus.GRCm39.115.gtf.gz
# Out:
# --2025-09-30 13:38:47--  https://ftp.ensembl.org/pub/release-115/fasta/mus_musculus/dna/Mus_musculus.GRCm39.dna.toplevel.fa.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 806418890 (769M) [application/x-gzip]
# Saving to: ‘Mus_musculus.GRCm39.dna.toplevel.fa.gz’
#
# Mus_musculus.GRCm39 100%[===================>] 769.06M  5.94MB/s    in 2m 27s
#
# 2025-09-30 13:41:22 (5.22 MB/s) - ‘Mus_musculus.GRCm39.dna.toplevel.fa.gz’ saved [806418890/806418890]
#
# --2025-09-30 13:41:22--  https://ftp.ensembl.org/pub/release-115/gtf/mus_musculus/Mus_musculus.GRCm39.115.gtf.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41681142 (40M) [application/x-gzip]
# Saving to: ‘Mus_musculus.GRCm39.115.gtf.gz’
#
# Mus_musculus.GRCm39 100%[===================>]  39.75M  4.12MB/s    in 9.5s
#
# 2025-09-30 13:41:34 (4.20 MB/s) - ‘Mus_musculus.GRCm39.115.gtf.gz’ saved [41681142/41681142]

# %%
# --genome GRCm39
# post here the command you used to run nf-core/rnaseq
# !nextflow run nf-core/rnaseq \
    -r 3.21.0 \
    --input samplesheet.csv \
    --outdir rnaseq_out \
    --gtf Mus_musculus.GRCm39.115.gtf.gz \
    --fasta Mus_musculus.GRCm39.dna.toplevel.fa.gz \
    --save_align_intermeds \
    -profile docker \
    -c nextflow.config \
    -resume
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/rnaseq` [amazing_neumann] DSL2 - revision: 9738a2df42 [3.21.0]
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/rnaseq 3.21.0
# ------------------------------------------------------
# Input/output options
#   input               : samplesheet.csv
#   outdir              : rnaseq_out
#
# Reference genome options
#   fasta               : Mus_musculus.GRCm39.dna.toplevel.fa.gz
#   gtf                 : Mus_musculus.GRCm39.115.gtf.gz
#
# UMI options
#   umi_discard_read    : 0
#
# Optional outputs
#   save_align_intermeds: true
#
# Generic options
#   trace_report_suffix : 2025-10-01_05-46-15
#
# Core Nextflow options
#   revision            : 3.21.0
#   runName             : amazing_neumann
#   containerEngine     : docker
#   launchDir           : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_02
#   workDir             : /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_02/work
#   projectDir          : /home/n_oswald/.nextflow/assets/nf-core/rnaseq
#   userName            : n_oswald
#   profile             : docker
#   configFiles         : /home/n_oswald/.nextflow/assets/nf-core/rnaseq/nextflow.config, /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_02/nextflow.config, /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_02/nextflow.config
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# * The pipeline
#     https://doi.org/10.5281/zenodo.1400710
#
# * The nf-core framework
#     https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#     https://github.com/nf-core/rnaseq/blob/master/CITATIONS.md
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 2 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 3 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 5 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 6 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 7 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 8 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 9 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 11 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 13 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 14 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 16 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 17 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 19 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 21 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 23 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 24 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 25 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 26 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 27 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 28 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 29 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 30 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 31 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [-        ] NFC…:PREPARE_GENOME:GUNZIP_GTF -
# [-        ] NFC…REPARE_GENOME:GUNZIP_FASTA -
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [-        ] NFC…ER_SETSTRANDEDNESS:FQ_LINT -
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [-        ] NFC…:PREPARE_GENOME:GTF_FILTER -
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [-        ] NFC…ENOME:CUSTOM_GETCHROMSIZES -
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [ca/4d7b7f] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [-        ] NFC…UMITOOLS_TRIMGALORE:FASTQC -
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [ca/4d7b7f] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [90/ab3447] NFC…RIMGALORE:FASTQC (SNI-Oxy) | 1 of 1, cached: 1
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [ca/4d7b7f] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE -
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [47/857fe2] NFC…IMGALORE:FASTQC (Sham-Oxy) | 2 of 2, cached: 2
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [-        ] NFC…OME:MAKE_TRANSCRIPTS_FASTA -
# [ca/4d7b7f] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [47/857fe2] NFC…IMGALORE:FASTQC (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [-        ] NFC…OOLS_TRIMGALORE:TRIMGALORE -
# [-        ] NFC…ESS:FQ_LINT_AFTER_TRIMMING -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_INDEX -
# [-        ] NFC…PLE_FQ_SALMON:FQ_SUBSAMPLE -
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# WARN: The operator `first` is useless when applied to a value channel which returns a single value by definition
#
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [-        ] NFC…SEQ:PREPARE_GENOME:GTF2BED -
# [3b/08e2a6] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [ca/4d7b7f] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [-        ] NFC…GENOME:STAR_GENOMEGENERATE | 0 of 1
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# ...
#   Oct 01 05:38:51 ... starting to generate Genome files
#   Oct 01 05:41:17 ..... processing annotations GTF
#   Oct 01 05:42:33 ... starting to sort Suffix Array. This may take a long time...
#   Oct 01 05:42:45 ... sorting Suffix Array chunks and saving them to disk...
#   Oct 01 06:16:08 ... loading chunks from disk, packing SA...
#
# Command error:
#   WARNING: Error parsing config file (/home/n_oswald/.docker/config.json): invalid character '}' looking for beginning of object key string
#   	/opt/conda/bin/STAR-avx2 --runMode genomeGenerate --genomeDir star/ --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf --runThreadN 16 --genomeSAindexNbases 14 --limitGenomeGenerateRAM 12784901888
#   	STAR version: 2.7.11b   compiled: 2025-01-09T12:32:06+0000 :/opt/conda/conda-bld/star_1736425784849/work/source
#   Oct 01 05:38:51 ..... started STAR run
#   Oct 01 05:38:51 ... starting to generate Genome files
#   Oct 01 05:41:17 ..... processing annotations GTF
#   Oct 01 05:42:33 ... starting to sort Suffix Array. This may take a long time...
#   Oct 01 05:42:45 ... sorting Suffix Array chunks and saving them to disk...
#   Oct 01 06:16:08 ... loading chunks from disk, packing SA...
#   /opt/conda/bin/STAR: line 8:   816 Killed                  "${cmd}" "$@"
#
# Work dir:
#   /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_02/work/8c/3b91f9e08698a49472114f6011589b
#
# Container:
#   community.wave.seqera.io/library/htslib_samtools_star_gawk:ae438e9a604351a4
#
# Tip: you can try to figure out what's wrong by changing to the process work dir and showing the script file named `.command.sh`
#
#  -- Check '.nextflow.log' file for details
#
# executor >  local (6)
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [ff/54b605] NFC…s.GRCm39.115.filtered.gtf) | 1 of 1, cached: 1 ✔
# [3b/08e2a6] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [ca/4d7b7f] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [8c/3b91f9] NFC…us.GRCm39.dna.toplevel.fa) | 0 of 1, retries: 1 ✘
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [47/857fe2] NFC…IMGALORE:FASTQC (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [cf/a0649c] NFC…LORE:TRIMGALORE (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [77/087580] NFC…_AFTER_TRIMMING (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [98/7388fb] NFC…EX (genome.transcripts.fa) | 0 of 1, retries: 1
# [bc/8083d8] NFC…ON:FQ_SUBSAMPLE (Sham-Oxy) | 2 of 2 ✔
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE (Mus_musculus.GRCm39.dna.toplevel.fa)'
#
# Caused by:
#   Process `NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE (Mus_musculus.GRCm39.dna.toplevel.fa)` terminated with an error exit status (137)
#
#
# Command executed:
#
#   samtools faidx Mus_musculus.GRCm39.dna.toplevel.fa
#   NUM_BASES=`gawk '{sum = sum + $2}END{if ((log(sum)/log(2))/2 - 1 > 14) {printf "%.0f", 14} else {printf "%.0f", (log(sum)/log(2))/2 - 1}}' Mus_musculus.GRCm39.dna.toplevel.fa.fai`
#
#   mkdir star
#   STAR \
#       --runMode genomeGenerate \
#       --genomeDir star/ \
#       --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa \
#       --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf \
#       --runThreadN 16 \
#       --genomeSAindexNbases $NUM_BASES \
#       --limitGenomeGenerateRAM 12784901888 \
#
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE":
#       star: $(STAR --version | sed -e "s/STAR_//g")
#       samtools: $(echo $(samtools --version 2>&1) | sed 's/^.*samtools //; s/Using.*$//')
#       gawk: $(echo $(gawk --version 2>&1) | sed 's/^.*GNU Awk //; s/, .*$//')
#   END_VERSIONS
#
# Command exit status:
#   137
#
# Command output:
#   	/opt/conda/bin/STAR-avx2 --runMode genomeGenerate --genomeDir star/ --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf --runThreadN 16 --genomeSAindexNbases 14 --limitGenomeGenerateRAM 12784901888
#   	STAR version: 2.7.11b   compiled: 2025-01-09T12:32:06+0000 :/opt/conda/conda-bld/star_1736425784849/work/source
#   Oct 01 05:38:51 ..... started STAR run
#   Oct 01 05:38:51 ... starting to generate Genome files
#   Oct 01 05:41:17 ..... processing annotations GTF
#   Oct 01 05:42:33 ... starting to sort Suffix Array. This may take a long time...
#   Oct 01 05:42:45 ... sorting Suffix Array chunks and saving them to disk...
#   Oct 01 06:16:08 ... loading chunks from disk, packing SA...
#
# Command error:
#   WARNING: Error parsing config file (/home/n_oswald/.docker/config.json): invalid character '}' looking for beginning of object key string
#   	/opt/conda/bin/STAR-avx2 --runMode genomeGenerate --genomeDir star/ --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf --runThreadN 16 --genomeSAindexNbases 14 --limitGenomeGenerateRAM 12784901888
#   	STAR version: 2.7.11b   compiled: 2025-01-09T12:32:06+0000 :/opt/conda/conda-bld/star_1736425784849/work/source
#   Oct 01 05:38:51 ..... started STAR run
#   Oct 01 05:38:51 ... starting to generate Genome files
#   Oct 01 05:41:17 ..... processing annotations GTF
#   Oct 01 05:42:33 ... starting to sort Suffix Array. This may take a long time...
#   Oct 01 05:42:45 ... sorting Suffix Array chunks and saving them to disk...
#   Oct 01 06:16:08 ... loading chunks from disk, packing SA...
#   /opt/conda/bin/STAR: line 8:   816 Killed                  "${cmd}" "$@"
#
# Work dir:
#   /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_02/work/8c/3b91f9e08698a49472114f6011589b
#
# Container:
#   community.wave.seqera.io/library/htslib_samtools_star_gawk:ae438e9a604351a4
#
# Tip: you can try to figure out what's wrong by changing to the process work dir and showing the script file named `.command.sh`
#
#  -- Check '.nextflow.log' file for details
#
# executor >  local (6)
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [ff/54b605] NFC…s.GRCm39.115.filtered.gtf) | 1 of 1, cached: 1 ✔
# [3b/08e2a6] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [ca/4d7b7f] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [8c/3b91f9] NFC…us.GRCm39.dna.toplevel.fa) | 0 of 1, retries: 1 ✘
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [47/857fe2] NFC…IMGALORE:FASTQC (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [cf/a0649c] NFC…LORE:TRIMGALORE (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [77/087580] NFC…_AFTER_TRIMMING (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [98/7388fb] NFC…EX (genome.transcripts.fa) | 0 of 1, retries: 1
# [bc/8083d8] NFC…ON:FQ_SUBSAMPLE (Sham-Oxy) | 2 of 2 ✔
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE (Mus_musculus.GRCm39.dna.toplevel.fa)'
#
# Caused by:
#   Process `NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE (Mus_musculus.GRCm39.dna.toplevel.fa)` terminated with an error exit status (137)
#
#
# Command executed:
#
#   samtools faidx Mus_musculus.GRCm39.dna.toplevel.fa
#   NUM_BASES=`gawk '{sum = sum + $2}END{if ((log(sum)/log(2))/2 - 1 > 14) {printf "%.0f", 14} else {printf "%.0f", (log(sum)/log(2))/2 - 1}}' Mus_musculus.GRCm39.dna.toplevel.fa.fai`
#
#   mkdir star
#   STAR \
#       --runMode genomeGenerate \
#       --genomeDir star/ \
#       --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa \
#       --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf \
#       --runThreadN 16 \
#       --genomeSAindexNbases $NUM_BASES \
#       --limitGenomeGenerateRAM 12784901888 \
#
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE":
#       star: $(STAR --version | sed -e "s/STAR_//g")
#       samtools: $(echo $(samtools --version 2>&1) | sed 's/^.*samtools //; s/Using.*$//')
#       gawk: $(echo $(gawk --version 2>&1) | sed 's/^.*GNU Awk //; s/, .*$//')
#   END_VERSIONS
#
# Command exit status:
#   137
#
# Command output:
#   	/opt/conda/bin/STAR-avx2 --runMode genomeGenerate --genomeDir star/ --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf --runThreadN 16 --genomeSAindexNbases 14 --limitGenomeGenerateRAM 12784901888
#   	STAR version: 2.7.11b   compiled: 2025-01-09T12:32:06+0000 :/opt/conda/conda-bld/star_1736425784849/work/source
#   Oct 01 05:38:51 ..... started STAR run
#   Oct 01 05:38:51 ... starting to generate Genome files
#   Oct 01 05:41:17 ..... processing annotations GTF
#   Oct 01 05:42:33 ... starting to sort Suffix Array. This may take a long time...
#   Oct 01 05:42:45 ... sorting Suffix Array chunks and saving them to disk...
#   Oct 01 06:16:08 ... loading chunks from disk, packing SA...
#
# Command error:
#   WARNING: Error parsing config file (/home/n_oswald/.docker/config.json): invalid character '}' looking for beginning of object key string
#   	/opt/conda/bin/STAR-avx2 --runMode genomeGenerate --genomeDir star/ --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf --runThreadN 16 --genomeSAindexNbases 14 --limitGenomeGenerateRAM 12784901888
#   	STAR version: 2.7.11b   compiled: 2025-01-09T12:32:06+0000 :/opt/conda/conda-bld/star_1736425784849/work/source
#   Oct 01 05:38:51 ..... started STAR run
#   Oct 01 05:38:51 ... starting to generate Genome files
#   Oct 01 05:41:17 ..... processing annotations GTF
#   Oct 01 05:42:33 ... starting to sort Suffix Array. This may take a long time...
#   Oct 01 05:42:45 ... sorting Suffix Array chunks and saving them to disk...
#   Oct 01 06:16:08 ... loading chunks from disk, packing SA...
#   /opt/conda/bin/STAR: line 8:   816 Killed                  "${cmd}" "$@"
#
# Work dir:
#   /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_02/work/8c/3b91f9e08698a49472114f6011589b
#
# Container:
#   community.wave.seqera.io/library/htslib_samtools_star_gawk:ae438e9a604351a4
#
# Tip: you can try to figure out what's wrong by changing to the process work dir and showing the script file named `.command.sh`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details
# -[nf-core/rnaseq] Pipeline completed with errors-
# WARN: Killing running tasks (1)
#
# executor >  local (6)
# [69/7c3207] NFC…usculus.GRCm39.115.gtf.gz) | 1 of 1, cached: 1 ✔
# [1e/384e66] NFC…GRCm39.dna.toplevel.fa.gz) | 1 of 1, cached: 1 ✔
# [76/225972] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [ff/54b605] NFC…s.GRCm39.115.filtered.gtf) | 1 of 1, cached: 1 ✔
# [3b/08e2a6] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [ca/4d7b7f] NFC…us.GRCm39.dna.toplevel.fa) | 1 of 1, cached: 1 ✔
# [8c/3b91f9] NFC…us.GRCm39.dna.toplevel.fa) | 0 of 1, retries: 1 ✘
# [-        ] NFC…ASEQ:RNASEQ:SAMTOOLS_INDEX -
# [-        ] NFC…_SETSTRANDEDNESS:CAT_FASTQ -
# [2f/cfd314] NFC…DEDNESS:FQ_LINT (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [47/857fe2] NFC…IMGALORE:FASTQC (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [cf/a0649c] NFC…LORE:TRIMGALORE (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [77/087580] NFC…_AFTER_TRIMMING (Sham-Oxy) | 2 of 2, cached: 2 ✔
# [98/7388fb] NFC…EX (genome.transcripts.fa) | 0 of 1, retries: 1
# [bc/8083d8] NFC…ON:FQ_SUBSAMPLE (Sham-Oxy) | 2 of 2 ✔
# [-        ] NFC…PLE_FQ_SALMON:SALMON_QUANT -
# [-        ] NFC…ASEQ:ALIGN_STAR:STAR_ALIGN -
# [-        ] NFC…ATS_SAMTOOLS:SAMTOOLS_SORT -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_INDEX -
# [-        ] NFC…TS_SAMTOOLS:SAMTOOLS_STATS -
# Plus 32 more processes waiting for tasks…
# ERROR ~ Error executing process > 'NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE (Mus_musculus.GRCm39.dna.toplevel.fa)'
#
# Caused by:
#   Process `NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE (Mus_musculus.GRCm39.dna.toplevel.fa)` terminated with an error exit status (137)
#
#
# Command executed:
#
#   samtools faidx Mus_musculus.GRCm39.dna.toplevel.fa
#   NUM_BASES=`gawk '{sum = sum + $2}END{if ((log(sum)/log(2))/2 - 1 > 14) {printf "%.0f", 14} else {printf "%.0f", (log(sum)/log(2))/2 - 1}}' Mus_musculus.GRCm39.dna.toplevel.fa.fai`
#
#   mkdir star
#   STAR \
#       --runMode genomeGenerate \
#       --genomeDir star/ \
#       --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa \
#       --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf \
#       --runThreadN 16 \
#       --genomeSAindexNbases $NUM_BASES \
#       --limitGenomeGenerateRAM 12784901888 \
#
#
#   cat <<-END_VERSIONS > versions.yml
#   "NFCORE_RNASEQ:PREPARE_GENOME:STAR_GENOMEGENERATE":
#       star: $(STAR --version | sed -e "s/STAR_//g")
#       samtools: $(echo $(samtools --version 2>&1) | sed 's/^.*samtools //; s/Using.*$//')
#       gawk: $(echo $(gawk --version 2>&1) | sed 's/^.*GNU Awk //; s/, .*$//')
#   END_VERSIONS
#
# Command exit status:
#   137
#
# Command output:
#   	/opt/conda/bin/STAR-avx2 --runMode genomeGenerate --genomeDir star/ --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf --runThreadN 16 --genomeSAindexNbases 14 --limitGenomeGenerateRAM 12784901888
#   	STAR version: 2.7.11b   compiled: 2025-01-09T12:32:06+0000 :/opt/conda/conda-bld/star_1736425784849/work/source
#   Oct 01 05:38:51 ..... started STAR run
#   Oct 01 05:38:51 ... starting to generate Genome files
#   Oct 01 05:41:17 ..... processing annotations GTF
#   Oct 01 05:42:33 ... starting to sort Suffix Array. This may take a long time...
#   Oct 01 05:42:45 ... sorting Suffix Array chunks and saving them to disk...
#   Oct 01 06:16:08 ... loading chunks from disk, packing SA...
#
# Command error:
#   WARNING: Error parsing config file (/home/n_oswald/.docker/config.json): invalid character '}' looking for beginning of object key string
#   	/opt/conda/bin/STAR-avx2 --runMode genomeGenerate --genomeDir star/ --genomeFastaFiles Mus_musculus.GRCm39.dna.toplevel.fa --sjdbGTFfile Mus_musculus.GRCm39.115.filtered.gtf --runThreadN 16 --genomeSAindexNbases 14 --limitGenomeGenerateRAM 12784901888
#   	STAR version: 2.7.11b   compiled: 2025-01-09T12:32:06+0000 :/opt/conda/conda-bld/star_1736425784849/work/source
#   Oct 01 05:38:51 ..... started STAR run
#   Oct 01 05:38:51 ... starting to generate Genome files
#   Oct 01 05:41:17 ..... processing annotations GTF
#   Oct 01 05:42:33 ... starting to sort Suffix Array. This may take a long time...
#   Oct 01 05:42:45 ... sorting Suffix Array chunks and saving them to disk...
#   Oct 01 06:16:08 ... loading chunks from disk, packing SA...
#   /opt/conda/bin/STAR: line 8:   816 Killed                  "${cmd}" "$@"
#
# Work dir:
#   /mnt/c/Users/NicolaiOswald/OneDrive - UT Cloud/Dokumente/Studium Tübingen/Computational Workflows/computational-workflows-2025/notebooks/day_02/work/8c/3b91f9e08698a49472114f6011589b
#
# Container:
#   community.wave.seqera.io/library/htslib_samtools_star_gawk:ae438e9a604351a4
#
# Tip: you can try to figure out what's wrong by changing to the process work dir and showing the script file named `.command.sh`
#
#  -- Check '.nextflow.log' file for details
# ERROR ~ Pipeline failed. Please refer to troubleshooting docs: https://nf-co.re/docs/usage/troubleshooting
#
#  -- Check '.nextflow.log' file for details

# %% [markdown]
# Explain all the parameters you set and why you set them in this way.

# %% [markdown]
# - `-r` version for reproducibility
# - `--input` specify samplesheet as input
# - `--outdir` directory to write results into
# - `-profile` run docker container
#
#
# - `--fasta` reference genome GRCm39 for Mus musculus
# - `--gtf` gene annotations to for the reference
#
# alternatively the `--genome`flag can be set specifying the reference genome GRCm39
#
# - `--save_align_intermeds` save intermediate steps when gererating BAM files for later usage, future runs can use the parameter `--skip_alignment` to reuse BAM files
# - `-c` specify config file for memory constraints
# - `-resume` from previous runs

# %% [markdown]
# ## Browsing the results

# %% [markdown]
# How did the pipeline perform?

# %% [markdown]
# Explain the quality control steps. Are you happy with the quality and why. If not, why not.
# Please give additional information on :
# - ribosomal rRNA
# - Duplication
# - GC content
#
# What are the possible steps that could lead to poorer results?

# %% [markdown]
# Would you exclude any samples? If yes, which and why?

# %% [markdown]
# What would you now do to continue the experiment? What are the scientists trying to figure out? Which packages on R or python would you use?
